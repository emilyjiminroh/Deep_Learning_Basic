# %% [markdown]
# ## Linear Regression의 주요 특징!
# #### 목표: (모델값-실측치)^2 의 오차를 최소화하는 W와 b를 찾아라!
# - 이때 손실함수는 모든 (모델값-실측치)^2의 평균
# - y축을 오차, x축을 Weight로 한 그래프를 그렸을 때 종형이면, Convex함!
#     - => 즉! 경사하강법을 통해 손실함수를 최소화하는 W와 b값을 구할 수 있음!
# #### 경사하강법에서 주의해야하는 점
#     - Learning Rates를 너무 크게 설정하면 => overshooting 발생(최소인 지점을 건너띔)
#     - Learning Rates를 너무 작게 설정하면 => 너무 오랜 시간이 걸림
#         - => 즉. 항상 보정값인 알파 값을 곱해주어 적절한 비율에 맞는 연산을 하도록 조정

# %%
import torch

# %%
# 학습시킬 데이터
x_train = torch.FloatTensor([[1,1],[2,2],[3,3]]) 
y_train = torch.FloatTensor([[10],[20],[30]])
# weight, bias 랜덤값으로 초기화
W = torch.randn([2,1],requires_grad=True)
b = torch.randn([1],requires_grad=True)
# 확률적 경사 하강법을 사용해 모델 파라미터 업데이트
optimizer = torch.optim.SGD([W,b],lr = 0.01)

# %%
# 모델링
def modle_LinearRegression(x):
    return torch.matmul(x,W)+b # W*x+b 반환

for step in range(2000):
    prediction = modle_LinearRegression(x_train) # 모델에 입력값을 넣어 예측값 반환
    cost = torch.mean((prediction - y_train)**2) # 오차의 손실함수 계산
    optimizer.zero_grad() # optimizer의 gradient 초기화
    cost.backward() # 손실함수를 미분하여 gradient 계산
    optimizer.step() #계산된 gradient를 사용하여 모델 파라미터를 업데이트
    print("Current Value of [w,b] = [[%.2f,%.2f],%.2f]"%(W[0,0],W[1,0],b)) #학습 중간 업데이트 과정 출력

# 모델 테스트 과정
x_test = torch.FloatTensor([[4,4]]) # [4,4]를 입력으로 받을때
model_test = modle_LinearRegression(x_test) # 예측 값
print('='*100)
print("Model with [4] (expectation:40): ",model_test.detach().item()) # 텐서였던 모델의 출력값을 스칼라 값으로 변환하여 반환함
print('='*100)
# Out:
# Current Value of [w,b] = [[0.64,2.28],0.35]
# Current Value of [w,b] = [[1.29,2.92],0.63]
# Current Value of [w,b] = [[1.80,3.44],0.85]
# Current Value of [w,b] = [[2.21,3.85],1.02]
# Current Value of [w,b] = [[2.54,4.18],1.16]
# Current Value of [w,b] = [[2.80,4.44],1.27]
# Current Value of [w,b] = [[3.01,4.64],1.35]
# Current Value of [w,b] = [[3.17,4.81],1.42]
# Current Value of [w,b] = [[3.30,4.94],1.47]
# Current Value of [w,b] = [[3.41,5.05],1.51]
# Current Value of [w,b] = [[3.49,5.13],1.54]
# Current Value of [w,b] = [[3.56,5.20],1.57]
# Current Value of [w,b] = [[3.61,5.25],1.59]
# Current Value of [w,b] = [[3.65,5.29],1.60]
# Current Value of [w,b] = [[3.69,5.33],1.61]
# Current Value of [w,b] = [[3.72,5.35],1.62]
# Current Value of [w,b] = [[3.74,5.38],1.62]
# Current Value of [w,b] = [[3.76,5.39],1.62]
# Current Value of [w,b] = [[3.77,5.41],1.63]
# Current Value of [w,b] = [[3.78,5.42],1.63]
# Current Value of [w,b] = [[3.79,5.43],1.63]
# Current Value of [w,b] = [[3.80,5.44],1.62]
# Current Value of [w,b] = [[3.81,5.44],1.62]
# Current Value of [w,b] = [[3.81,5.45],1.62]
# Current Value of [w,b] = [[3.81,5.45],1.62]
# Current Value of [w,b] = [[3.82,5.46],1.61]
# Current Value of [w,b] = [[3.82,5.46],1.61]
# Current Value of [w,b] = [[3.82,5.46],1.61]
# Current Value of [w,b] = [[3.83,5.46],1.60]
# Current Value of [w,b] = [[3.83,5.47],1.60]
# Current Value of [w,b] = [[3.83,5.47],1.60]
# Current Value of [w,b] = [[3.83,5.47],1.59]
# Current Value of [w,b] = [[3.83,5.47],1.59]
# Current Value of [w,b] = [[3.83,5.47],1.58]
# Current Value of [w,b] = [[3.84,5.47],1.58]
# Current Value of [w,b] = [[3.84,5.48],1.58]
# Current Value of [w,b] = [[3.84,5.48],1.57]
# Current Value of [w,b] = [[3.84,5.48],1.57]
# Current Value of [w,b] = [[3.84,5.48],1.56]
# Current Value of [w,b] = [[3.84,5.48],1.56]
# Current Value of [w,b] = [[3.84,5.48],1.56]
# Current Value of [w,b] = [[3.84,5.48],1.55]
# Current Value of [w,b] = [[3.84,5.48],1.55]
# Current Value of [w,b] = [[3.85,5.48],1.54]
# Current Value of [w,b] = [[3.85,5.48],1.54]
# Current Value of [w,b] = [[3.85,5.49],1.54]
# Current Value of [w,b] = [[3.85,5.49],1.53]
# Current Value of [w,b] = [[3.85,5.49],1.53]
# Current Value of [w,b] = [[3.85,5.49],1.52]
# Current Value of [w,b] = [[3.85,5.49],1.52]
# Current Value of [w,b] = [[3.85,5.49],1.52]
# Current Value of [w,b] = [[3.85,5.49],1.51]
# Current Value of [w,b] = [[3.85,5.49],1.51]
# Current Value of [w,b] = [[3.85,5.49],1.50]
# Current Value of [w,b] = [[3.85,5.49],1.50]
# Current Value of [w,b] = [[3.86,5.49],1.50]
# Current Value of [w,b] = [[3.86,5.49],1.49]
# Current Value of [w,b] = [[3.86,5.50],1.49]
# Current Value of [w,b] = [[3.86,5.50],1.48]
# Current Value of [w,b] = [[3.86,5.50],1.48]
# Current Value of [w,b] = [[3.86,5.50],1.48]
# Current Value of [w,b] = [[3.86,5.50],1.47]
# Current Value of [w,b] = [[3.86,5.50],1.47]
# Current Value of [w,b] = [[3.86,5.50],1.47]
# Current Value of [w,b] = [[3.86,5.50],1.46]
# Current Value of [w,b] = [[3.86,5.50],1.46]
# Current Value of [w,b] = [[3.86,5.50],1.45]
# Current Value of [w,b] = [[3.87,5.50],1.45]
# Current Value of [w,b] = [[3.87,5.50],1.45]
# Current Value of [w,b] = [[3.87,5.51],1.44]
# Current Value of [w,b] = [[3.87,5.51],1.44]
# Current Value of [w,b] = [[3.87,5.51],1.43]
# Current Value of [w,b] = [[3.87,5.51],1.43]
# Current Value of [w,b] = [[3.87,5.51],1.43]
# Current Value of [w,b] = [[3.87,5.51],1.42]
# Current Value of [w,b] = [[3.87,5.51],1.42]
# Current Value of [w,b] = [[3.87,5.51],1.42]
# Current Value of [w,b] = [[3.87,5.51],1.41]
# Current Value of [w,b] = [[3.87,5.51],1.41]
# Current Value of [w,b] = [[3.88,5.51],1.41]
# Current Value of [w,b] = [[3.88,5.51],1.40]
# Current Value of [w,b] = [[3.88,5.52],1.40]
# Current Value of [w,b] = [[3.88,5.52],1.39]
# Current Value of [w,b] = [[3.88,5.52],1.39]
# Current Value of [w,b] = [[3.88,5.52],1.39]
# Current Value of [w,b] = [[3.88,5.52],1.38]
# Current Value of [w,b] = [[3.88,5.52],1.38]
# Current Value of [w,b] = [[3.88,5.52],1.38]
# Current Value of [w,b] = [[3.88,5.52],1.37]
# Current Value of [w,b] = [[3.88,5.52],1.37]
# Current Value of [w,b] = [[3.88,5.52],1.37]
# Current Value of [w,b] = [[3.88,5.52],1.36]
# Current Value of [w,b] = [[3.89,5.52],1.36]
# Current Value of [w,b] = [[3.89,5.52],1.35]
# Current Value of [w,b] = [[3.89,5.53],1.35]
# Current Value of [w,b] = [[3.89,5.53],1.35]
# Current Value of [w,b] = [[3.89,5.53],1.34]
# Current Value of [w,b] = [[3.89,5.53],1.34]
# Current Value of [w,b] = [[3.89,5.53],1.34]
# Current Value of [w,b] = [[3.89,5.53],1.33]
# Current Value of [w,b] = [[3.89,5.53],1.33]
# Current Value of [w,b] = [[3.89,5.53],1.33]
# Current Value of [w,b] = [[3.89,5.53],1.32]
# Current Value of [w,b] = [[3.89,5.53],1.32]
# Current Value of [w,b] = [[3.89,5.53],1.32]
# Current Value of [w,b] = [[3.90,5.53],1.31]
# Current Value of [w,b] = [[3.90,5.53],1.31]
# Current Value of [w,b] = [[3.90,5.54],1.31]
# Current Value of [w,b] = [[3.90,5.54],1.30]
# Current Value of [w,b] = [[3.90,5.54],1.30]
# Current Value of [w,b] = [[3.90,5.54],1.30]
# Current Value of [w,b] = [[3.90,5.54],1.29]
# Current Value of [w,b] = [[3.90,5.54],1.29]
# Current Value of [w,b] = [[3.90,5.54],1.29]
# Current Value of [w,b] = [[3.90,5.54],1.28]
# Current Value of [w,b] = [[3.90,5.54],1.28]
# Current Value of [w,b] = [[3.90,5.54],1.28]
# Current Value of [w,b] = [[3.90,5.54],1.27]
# Current Value of [w,b] = [[3.91,5.54],1.27]
# Current Value of [w,b] = [[3.91,5.54],1.27]
# Current Value of [w,b] = [[3.91,5.54],1.26]
# Current Value of [w,b] = [[3.91,5.55],1.26]
# Current Value of [w,b] = [[3.91,5.55],1.26]
# Current Value of [w,b] = [[3.91,5.55],1.25]
# Current Value of [w,b] = [[3.91,5.55],1.25]
# Current Value of [w,b] = [[3.91,5.55],1.25]
# Current Value of [w,b] = [[3.91,5.55],1.24]
# Current Value of [w,b] = [[3.91,5.55],1.24]
# Current Value of [w,b] = [[3.91,5.55],1.24]
# Current Value of [w,b] = [[3.91,5.55],1.23]
# Current Value of [w,b] = [[3.91,5.55],1.23]
# Current Value of [w,b] = [[3.91,5.55],1.23]
# Current Value of [w,b] = [[3.92,5.55],1.22]
# Current Value of [w,b] = [[3.92,5.55],1.22]
# Current Value of [w,b] = [[3.92,5.55],1.22]
# Current Value of [w,b] = [[3.92,5.56],1.21]
# Current Value of [w,b] = [[3.92,5.56],1.21]
# Current Value of [w,b] = [[3.92,5.56],1.21]
# Current Value of [w,b] = [[3.92,5.56],1.20]
# Current Value of [w,b] = [[3.92,5.56],1.20]
# Current Value of [w,b] = [[3.92,5.56],1.20]
# Current Value of [w,b] = [[3.92,5.56],1.19]
# Current Value of [w,b] = [[3.92,5.56],1.19]
# Current Value of [w,b] = [[3.92,5.56],1.19]
# Current Value of [w,b] = [[3.92,5.56],1.19]
# Current Value of [w,b] = [[3.92,5.56],1.18]
# Current Value of [w,b] = [[3.92,5.56],1.18]
# Current Value of [w,b] = [[3.93,5.56],1.18]
# Current Value of [w,b] = [[3.93,5.56],1.17]
# Current Value of [w,b] = [[3.93,5.56],1.17]
# Current Value of [w,b] = [[3.93,5.57],1.17]
# Current Value of [w,b] = [[3.93,5.57],1.16]
# Current Value of [w,b] = [[3.93,5.57],1.16]
# Current Value of [w,b] = [[3.93,5.57],1.16]
# Current Value of [w,b] = [[3.93,5.57],1.15]
# Current Value of [w,b] = [[3.93,5.57],1.15]
# Current Value of [w,b] = [[3.93,5.57],1.15]
# Current Value of [w,b] = [[3.93,5.57],1.15]
# Current Value of [w,b] = [[3.93,5.57],1.14]
# Current Value of [w,b] = [[3.93,5.57],1.14]
# Current Value of [w,b] = [[3.93,5.57],1.14]
# Current Value of [w,b] = [[3.93,5.57],1.13]
# Current Value of [w,b] = [[3.94,5.57],1.13]
# Current Value of [w,b] = [[3.94,5.57],1.13]
# Current Value of [w,b] = [[3.94,5.57],1.12]
# Current Value of [w,b] = [[3.94,5.58],1.12]
# Current Value of [w,b] = [[3.94,5.58],1.12]
# Current Value of [w,b] = [[3.94,5.58],1.12]
# Current Value of [w,b] = [[3.94,5.58],1.11]
# Current Value of [w,b] = [[3.94,5.58],1.11]
# Current Value of [w,b] = [[3.94,5.58],1.11]
# Current Value of [w,b] = [[3.94,5.58],1.10]
# Current Value of [w,b] = [[3.94,5.58],1.10]
# Current Value of [w,b] = [[3.94,5.58],1.10]
# Current Value of [w,b] = [[3.94,5.58],1.10]
# Current Value of [w,b] = [[3.94,5.58],1.09]
# Current Value of [w,b] = [[3.94,5.58],1.09]
# Current Value of [w,b] = [[3.94,5.58],1.09]
# Current Value of [w,b] = [[3.95,5.58],1.08]
# Current Value of [w,b] = [[3.95,5.58],1.08]
# Current Value of [w,b] = [[3.95,5.58],1.08]
# Current Value of [w,b] = [[3.95,5.59],1.08]
# Current Value of [w,b] = [[3.95,5.59],1.07]
# Current Value of [w,b] = [[3.95,5.59],1.07]
# Current Value of [w,b] = [[3.95,5.59],1.07]
# Current Value of [w,b] = [[3.95,5.59],1.06]
# Current Value of [w,b] = [[3.95,5.59],1.06]
# Current Value of [w,b] = [[3.95,5.59],1.06]
# Current Value of [w,b] = [[3.95,5.59],1.06]
# Current Value of [w,b] = [[3.95,5.59],1.05]
# Current Value of [w,b] = [[3.95,5.59],1.05]
# Current Value of [w,b] = [[3.95,5.59],1.05]
# Current Value of [w,b] = [[3.95,5.59],1.05]
# Current Value of [w,b] = [[3.95,5.59],1.04]
# Current Value of [w,b] = [[3.95,5.59],1.04]
# Current Value of [w,b] = [[3.96,5.59],1.04]
# Current Value of [w,b] = [[3.96,5.59],1.03]
# Current Value of [w,b] = [[3.96,5.59],1.03]
# Current Value of [w,b] = [[3.96,5.60],1.03]
# Current Value of [w,b] = [[3.96,5.60],1.03]
# Current Value of [w,b] = [[3.96,5.60],1.02]
# Current Value of [w,b] = [[3.96,5.60],1.02]
# Current Value of [w,b] = [[3.96,5.60],1.02]
# Current Value of [w,b] = [[3.96,5.60],1.02]
# Current Value of [w,b] = [[3.96,5.60],1.01]
# Current Value of [w,b] = [[3.96,5.60],1.01]
# Current Value of [w,b] = [[3.96,5.60],1.01]
# Current Value of [w,b] = [[3.96,5.60],1.01]
# Current Value of [w,b] = [[3.96,5.60],1.00]
# Current Value of [w,b] = [[3.96,5.60],1.00]
# Current Value of [w,b] = [[3.96,5.60],1.00]
# Current Value of [w,b] = [[3.96,5.60],0.99]
# Current Value of [w,b] = [[3.97,5.60],0.99]
# Current Value of [w,b] = [[3.97,5.60],0.99]
# Current Value of [w,b] = [[3.97,5.60],0.99]
# Current Value of [w,b] = [[3.97,5.61],0.98]
# Current Value of [w,b] = [[3.97,5.61],0.98]
# Current Value of [w,b] = [[3.97,5.61],0.98]
# Current Value of [w,b] = [[3.97,5.61],0.98]
# Current Value of [w,b] = [[3.97,5.61],0.97]
# Current Value of [w,b] = [[3.97,5.61],0.97]
# Current Value of [w,b] = [[3.97,5.61],0.97]
# Current Value of [w,b] = [[3.97,5.61],0.97]
# Current Value of [w,b] = [[3.97,5.61],0.96]
# Current Value of [w,b] = [[3.97,5.61],0.96]
# Current Value of [w,b] = [[3.97,5.61],0.96]
# Current Value of [w,b] = [[3.97,5.61],0.96]
# Current Value of [w,b] = [[3.97,5.61],0.95]
# Current Value of [w,b] = [[3.97,5.61],0.95]
# Current Value of [w,b] = [[3.97,5.61],0.95]
# Current Value of [w,b] = [[3.98,5.61],0.95]
# Current Value of [w,b] = [[3.98,5.61],0.94]
# Current Value of [w,b] = [[3.98,5.61],0.94]
# Current Value of [w,b] = [[3.98,5.62],0.94]
# Current Value of [w,b] = [[3.98,5.62],0.94]
# Current Value of [w,b] = [[3.98,5.62],0.93]
# Current Value of [w,b] = [[3.98,5.62],0.93]
# Current Value of [w,b] = [[3.98,5.62],0.93]
# Current Value of [w,b] = [[3.98,5.62],0.93]
# Current Value of [w,b] = [[3.98,5.62],0.92]
# Current Value of [w,b] = [[3.98,5.62],0.92]
# Current Value of [w,b] = [[3.98,5.62],0.92]
# Current Value of [w,b] = [[3.98,5.62],0.92]
# Current Value of [w,b] = [[3.98,5.62],0.91]
# Current Value of [w,b] = [[3.98,5.62],0.91]
# Current Value of [w,b] = [[3.98,5.62],0.91]
# Current Value of [w,b] = [[3.98,5.62],0.91]
# Current Value of [w,b] = [[3.98,5.62],0.91]
# Current Value of [w,b] = [[3.98,5.62],0.90]
# Current Value of [w,b] = [[3.99,5.62],0.90]
# Current Value of [w,b] = [[3.99,5.62],0.90]
# Current Value of [w,b] = [[3.99,5.62],0.90]
# Current Value of [w,b] = [[3.99,5.63],0.89]
# Current Value of [w,b] = [[3.99,5.63],0.89]
# Current Value of [w,b] = [[3.99,5.63],0.89]
# Current Value of [w,b] = [[3.99,5.63],0.89]
# Current Value of [w,b] = [[3.99,5.63],0.88]
# Current Value of [w,b] = [[3.99,5.63],0.88]
# Current Value of [w,b] = [[3.99,5.63],0.88]
# Current Value of [w,b] = [[3.99,5.63],0.88]
# Current Value of [w,b] = [[3.99,5.63],0.87]
# Current Value of [w,b] = [[3.99,5.63],0.87]
# Current Value of [w,b] = [[3.99,5.63],0.87]
# Current Value of [w,b] = [[3.99,5.63],0.87]
# Current Value of [w,b] = [[3.99,5.63],0.87]
# Current Value of [w,b] = [[3.99,5.63],0.86]
# Current Value of [w,b] = [[3.99,5.63],0.86]
# Current Value of [w,b] = [[3.99,5.63],0.86]
# Current Value of [w,b] = [[3.99,5.63],0.86]
# Current Value of [w,b] = [[4.00,5.63],0.85]
# Current Value of [w,b] = [[4.00,5.63],0.85]
# Current Value of [w,b] = [[4.00,5.63],0.85]
# Current Value of [w,b] = [[4.00,5.63],0.85]
# Current Value of [w,b] = [[4.00,5.64],0.85]
# Current Value of [w,b] = [[4.00,5.64],0.84]
# Current Value of [w,b] = [[4.00,5.64],0.84]
# Current Value of [w,b] = [[4.00,5.64],0.84]
# Current Value of [w,b] = [[4.00,5.64],0.84]
# Current Value of [w,b] = [[4.00,5.64],0.83]
# Current Value of [w,b] = [[4.00,5.64],0.83]
# Current Value of [w,b] = [[4.00,5.64],0.83]
# Current Value of [w,b] = [[4.00,5.64],0.83]
# Current Value of [w,b] = [[4.00,5.64],0.83]
# Current Value of [w,b] = [[4.00,5.64],0.82]
# Current Value of [w,b] = [[4.00,5.64],0.82]
# Current Value of [w,b] = [[4.00,5.64],0.82]
# Current Value of [w,b] = [[4.00,5.64],0.82]
# Current Value of [w,b] = [[4.00,5.64],0.82]
# Current Value of [w,b] = [[4.00,5.64],0.81]
# Current Value of [w,b] = [[4.00,5.64],0.81]
# Current Value of [w,b] = [[4.01,5.64],0.81]
# Current Value of [w,b] = [[4.01,5.64],0.81]
# Current Value of [w,b] = [[4.01,5.64],0.80]
# Current Value of [w,b] = [[4.01,5.64],0.80]
# Current Value of [w,b] = [[4.01,5.65],0.80]
# Current Value of [w,b] = [[4.01,5.65],0.80]
# Current Value of [w,b] = [[4.01,5.65],0.80]
# Current Value of [w,b] = [[4.01,5.65],0.79]
# Current Value of [w,b] = [[4.01,5.65],0.79]
# Current Value of [w,b] = [[4.01,5.65],0.79]
# Current Value of [w,b] = [[4.01,5.65],0.79]
# Current Value of [w,b] = [[4.01,5.65],0.79]
# Current Value of [w,b] = [[4.01,5.65],0.78]
# Current Value of [w,b] = [[4.01,5.65],0.78]
# Current Value of [w,b] = [[4.01,5.65],0.78]
# Current Value of [w,b] = [[4.01,5.65],0.78]
# Current Value of [w,b] = [[4.01,5.65],0.78]
# Current Value of [w,b] = [[4.01,5.65],0.77]
# Current Value of [w,b] = [[4.01,5.65],0.77]
# Current Value of [w,b] = [[4.01,5.65],0.77]
# Current Value of [w,b] = [[4.01,5.65],0.77]
# Current Value of [w,b] = [[4.01,5.65],0.77]
# Current Value of [w,b] = [[4.01,5.65],0.76]
# Current Value of [w,b] = [[4.02,5.65],0.76]
# Current Value of [w,b] = [[4.02,5.65],0.76]
# Current Value of [w,b] = [[4.02,5.65],0.76]
# Current Value of [w,b] = [[4.02,5.65],0.76]
# Current Value of [w,b] = [[4.02,5.66],0.75]
# Current Value of [w,b] = [[4.02,5.66],0.75]
# Current Value of [w,b] = [[4.02,5.66],0.75]
# Current Value of [w,b] = [[4.02,5.66],0.75]
# Current Value of [w,b] = [[4.02,5.66],0.75]
# Current Value of [w,b] = [[4.02,5.66],0.74]
# Current Value of [w,b] = [[4.02,5.66],0.74]
# Current Value of [w,b] = [[4.02,5.66],0.74]
# Current Value of [w,b] = [[4.02,5.66],0.74]
# Current Value of [w,b] = [[4.02,5.66],0.74]
# Current Value of [w,b] = [[4.02,5.66],0.73]
# Current Value of [w,b] = [[4.02,5.66],0.73]
# Current Value of [w,b] = [[4.02,5.66],0.73]
# Current Value of [w,b] = [[4.02,5.66],0.73]
# Current Value of [w,b] = [[4.02,5.66],0.73]
# Current Value of [w,b] = [[4.02,5.66],0.72]
# Current Value of [w,b] = [[4.02,5.66],0.72]
# Current Value of [w,b] = [[4.02,5.66],0.72]
# Current Value of [w,b] = [[4.02,5.66],0.72]
# Current Value of [w,b] = [[4.02,5.66],0.72]
# Current Value of [w,b] = [[4.03,5.66],0.72]
# Current Value of [w,b] = [[4.03,5.66],0.71]
# Current Value of [w,b] = [[4.03,5.66],0.71]
# Current Value of [w,b] = [[4.03,5.66],0.71]
# Current Value of [w,b] = [[4.03,5.67],0.71]
# Current Value of [w,b] = [[4.03,5.67],0.71]
# Current Value of [w,b] = [[4.03,5.67],0.70]
# Current Value of [w,b] = [[4.03,5.67],0.70]
# Current Value of [w,b] = [[4.03,5.67],0.70]
# Current Value of [w,b] = [[4.03,5.67],0.70]
# Current Value of [w,b] = [[4.03,5.67],0.70]
# Current Value of [w,b] = [[4.03,5.67],0.69]
# Current Value of [w,b] = [[4.03,5.67],0.69]
# Current Value of [w,b] = [[4.03,5.67],0.69]
# Current Value of [w,b] = [[4.03,5.67],0.69]
# Current Value of [w,b] = [[4.03,5.67],0.69]
# Current Value of [w,b] = [[4.03,5.67],0.69]
# Current Value of [w,b] = [[4.03,5.67],0.68]
# Current Value of [w,b] = [[4.03,5.67],0.68]
# Current Value of [w,b] = [[4.03,5.67],0.68]
# Current Value of [w,b] = [[4.03,5.67],0.68]
# Current Value of [w,b] = [[4.03,5.67],0.68]
# Current Value of [w,b] = [[4.03,5.67],0.68]
# Current Value of [w,b] = [[4.03,5.67],0.67]
# Current Value of [w,b] = [[4.03,5.67],0.67]
# Current Value of [w,b] = [[4.04,5.67],0.67]
# Current Value of [w,b] = [[4.04,5.67],0.67]
# Current Value of [w,b] = [[4.04,5.67],0.67]
# Current Value of [w,b] = [[4.04,5.67],0.66]
# Current Value of [w,b] = [[4.04,5.68],0.66]
# Current Value of [w,b] = [[4.04,5.68],0.66]
# Current Value of [w,b] = [[4.04,5.68],0.66]
# Current Value of [w,b] = [[4.04,5.68],0.66]
# Current Value of [w,b] = [[4.04,5.68],0.66]
# Current Value of [w,b] = [[4.04,5.68],0.65]
# Current Value of [w,b] = [[4.04,5.68],0.65]
# Current Value of [w,b] = [[4.04,5.68],0.65]
# Current Value of [w,b] = [[4.04,5.68],0.65]
# Current Value of [w,b] = [[4.04,5.68],0.65]
# Current Value of [w,b] = [[4.04,5.68],0.65]
# Current Value of [w,b] = [[4.04,5.68],0.64]
# Current Value of [w,b] = [[4.04,5.68],0.64]
# Current Value of [w,b] = [[4.04,5.68],0.64]
# Current Value of [w,b] = [[4.04,5.68],0.64]
# Current Value of [w,b] = [[4.04,5.68],0.64]
# Current Value of [w,b] = [[4.04,5.68],0.64]
# Current Value of [w,b] = [[4.04,5.68],0.63]
# Current Value of [w,b] = [[4.04,5.68],0.63]
# Current Value of [w,b] = [[4.04,5.68],0.63]
# Current Value of [w,b] = [[4.04,5.68],0.63]
# Current Value of [w,b] = [[4.04,5.68],0.63]
# Current Value of [w,b] = [[4.04,5.68],0.63]
# Current Value of [w,b] = [[4.05,5.68],0.62]
# Current Value of [w,b] = [[4.05,5.68],0.62]
# Current Value of [w,b] = [[4.05,5.68],0.62]
# Current Value of [w,b] = [[4.05,5.68],0.62]
# Current Value of [w,b] = [[4.05,5.68],0.62]
# Current Value of [w,b] = [[4.05,5.69],0.62]
# Current Value of [w,b] = [[4.05,5.69],0.61]
# Current Value of [w,b] = [[4.05,5.69],0.61]
# Current Value of [w,b] = [[4.05,5.69],0.61]
# Current Value of [w,b] = [[4.05,5.69],0.61]
# Current Value of [w,b] = [[4.05,5.69],0.61]
# Current Value of [w,b] = [[4.05,5.69],0.61]
# Current Value of [w,b] = [[4.05,5.69],0.60]
# Current Value of [w,b] = [[4.05,5.69],0.60]
# Current Value of [w,b] = [[4.05,5.69],0.60]
# Current Value of [w,b] = [[4.05,5.69],0.60]
# Current Value of [w,b] = [[4.05,5.69],0.60]
# Current Value of [w,b] = [[4.05,5.69],0.60]
# Current Value of [w,b] = [[4.05,5.69],0.60]
# Current Value of [w,b] = [[4.05,5.69],0.59]
# Current Value of [w,b] = [[4.05,5.69],0.59]
# Current Value of [w,b] = [[4.05,5.69],0.59]
# Current Value of [w,b] = [[4.05,5.69],0.59]
# Current Value of [w,b] = [[4.05,5.69],0.59]
# Current Value of [w,b] = [[4.05,5.69],0.59]
# Current Value of [w,b] = [[4.05,5.69],0.58]
# Current Value of [w,b] = [[4.05,5.69],0.58]
# Current Value of [w,b] = [[4.05,5.69],0.58]
# Current Value of [w,b] = [[4.05,5.69],0.58]
# Current Value of [w,b] = [[4.06,5.69],0.58]
# Current Value of [w,b] = [[4.06,5.69],0.58]
# Current Value of [w,b] = [[4.06,5.69],0.58]
# Current Value of [w,b] = [[4.06,5.69],0.57]
# Current Value of [w,b] = [[4.06,5.69],0.57]
# Current Value of [w,b] = [[4.06,5.70],0.57]
# Current Value of [w,b] = [[4.06,5.70],0.57]
# Current Value of [w,b] = [[4.06,5.70],0.57]
# Current Value of [w,b] = [[4.06,5.70],0.57]
# Current Value of [w,b] = [[4.06,5.70],0.57]
# Current Value of [w,b] = [[4.06,5.70],0.56]
# Current Value of [w,b] = [[4.06,5.70],0.56]
# Current Value of [w,b] = [[4.06,5.70],0.56]
# Current Value of [w,b] = [[4.06,5.70],0.56]
# Current Value of [w,b] = [[4.06,5.70],0.56]
# Current Value of [w,b] = [[4.06,5.70],0.56]
# Current Value of [w,b] = [[4.06,5.70],0.55]
# Current Value of [w,b] = [[4.06,5.70],0.55]
# Current Value of [w,b] = [[4.06,5.70],0.55]
# Current Value of [w,b] = [[4.06,5.70],0.55]
# Current Value of [w,b] = [[4.06,5.70],0.55]
# Current Value of [w,b] = [[4.06,5.70],0.55]
# Current Value of [w,b] = [[4.06,5.70],0.55]
# Current Value of [w,b] = [[4.06,5.70],0.54]
# Current Value of [w,b] = [[4.06,5.70],0.54]
# Current Value of [w,b] = [[4.06,5.70],0.54]
# Current Value of [w,b] = [[4.06,5.70],0.54]
# Current Value of [w,b] = [[4.06,5.70],0.54]
# Current Value of [w,b] = [[4.06,5.70],0.54]
# Current Value of [w,b] = [[4.06,5.70],0.54]
# Current Value of [w,b] = [[4.06,5.70],0.53]
# Current Value of [w,b] = [[4.06,5.70],0.53]
# Current Value of [w,b] = [[4.07,5.70],0.53]
# Current Value of [w,b] = [[4.07,5.70],0.53]
# Current Value of [w,b] = [[4.07,5.70],0.53]
# Current Value of [w,b] = [[4.07,5.70],0.53]
# Current Value of [w,b] = [[4.07,5.70],0.53]
# Current Value of [w,b] = [[4.07,5.71],0.53]
# Current Value of [w,b] = [[4.07,5.71],0.52]
# Current Value of [w,b] = [[4.07,5.71],0.52]
# Current Value of [w,b] = [[4.07,5.71],0.52]
# Current Value of [w,b] = [[4.07,5.71],0.52]
# Current Value of [w,b] = [[4.07,5.71],0.52]
# Current Value of [w,b] = [[4.07,5.71],0.52]
# Current Value of [w,b] = [[4.07,5.71],0.52]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.51]
# Current Value of [w,b] = [[4.07,5.71],0.50]
# Current Value of [w,b] = [[4.07,5.71],0.50]
# Current Value of [w,b] = [[4.07,5.71],0.50]
# Current Value of [w,b] = [[4.07,5.71],0.50]
# Current Value of [w,b] = [[4.07,5.71],0.50]
# Current Value of [w,b] = [[4.07,5.71],0.50]
# Current Value of [w,b] = [[4.07,5.71],0.50]
# Current Value of [w,b] = [[4.07,5.71],0.49]
# Current Value of [w,b] = [[4.07,5.71],0.49]
# Current Value of [w,b] = [[4.07,5.71],0.49]
# Current Value of [w,b] = [[4.07,5.71],0.49]
# Current Value of [w,b] = [[4.07,5.71],0.49]
# Current Value of [w,b] = [[4.07,5.71],0.49]
# Current Value of [w,b] = [[4.08,5.71],0.49]
# Current Value of [w,b] = [[4.08,5.71],0.49]
# Current Value of [w,b] = [[4.08,5.71],0.48]
# Current Value of [w,b] = [[4.08,5.71],0.48]
# Current Value of [w,b] = [[4.08,5.71],0.48]
# Current Value of [w,b] = [[4.08,5.71],0.48]
# Current Value of [w,b] = [[4.08,5.72],0.48]
# Current Value of [w,b] = [[4.08,5.72],0.48]
# Current Value of [w,b] = [[4.08,5.72],0.48]
# Current Value of [w,b] = [[4.08,5.72],0.48]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.47]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.46]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.45]
# Current Value of [w,b] = [[4.08,5.72],0.44]
# Current Value of [w,b] = [[4.08,5.72],0.44]
# Current Value of [w,b] = [[4.08,5.72],0.44]
# Current Value of [w,b] = [[4.09,5.72],0.44]
# Current Value of [w,b] = [[4.09,5.72],0.44]
# Current Value of [w,b] = [[4.09,5.72],0.44]
# Current Value of [w,b] = [[4.09,5.72],0.44]
# Current Value of [w,b] = [[4.09,5.72],0.44]
# Current Value of [w,b] = [[4.09,5.72],0.44]
# Current Value of [w,b] = [[4.09,5.72],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.43]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.42]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.41]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.09,5.73],0.40]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.73],0.39]
# Current Value of [w,b] = [[4.10,5.74],0.39]
# Current Value of [w,b] = [[4.10,5.74],0.39]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.38]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.37]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.36]
# Current Value of [w,b] = [[4.10,5.74],0.35]
# Current Value of [w,b] = [[4.10,5.74],0.35]
# Current Value of [w,b] = [[4.10,5.74],0.35]
# Current Value of [w,b] = [[4.10,5.74],0.35]
# Current Value of [w,b] = [[4.10,5.74],0.35]
# Current Value of [w,b] = [[4.10,5.74],0.35]
# Current Value of [w,b] = [[4.10,5.74],0.35]
# Current Value of [w,b] = [[4.11,5.74],0.35]
# Current Value of [w,b] = [[4.11,5.74],0.35]
# Current Value of [w,b] = [[4.11,5.74],0.35]
# Current Value of [w,b] = [[4.11,5.74],0.35]
# Current Value of [w,b] = [[4.11,5.74],0.34]
# Current Value of [w,b] = [[4.11,5.74],0.34]
# Current Value of [w,b] = [[4.11,5.74],0.34]
# Current Value of [w,b] = [[4.11,5.74],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.34]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.33]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.32]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.31]
# Current Value of [w,b] = [[4.11,5.75],0.30]
# Current Value of [w,b] = [[4.11,5.75],0.30]
# Current Value of [w,b] = [[4.11,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.75],0.30]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.29]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.28]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.27]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.12,5.76],0.26]
# Current Value of [w,b] = [[4.13,5.76],0.26]
# Current Value of [w,b] = [[4.13,5.76],0.26]
# Current Value of [w,b] = [[4.13,5.76],0.26]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.76],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.25]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.24]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.23]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.22]
# Current Value of [w,b] = [[4.13,5.77],0.21]
# Current Value of [w,b] = [[4.13,5.77],0.21]
# Current Value of [w,b] = [[4.13,5.77],0.21]
# Current Value of [w,b] = [[4.13,5.77],0.21]
# Current Value of [w,b] = [[4.13,5.77],0.21]
# Current Value of [w,b] = [[4.13,5.77],0.21]
# Current Value of [w,b] = [[4.13,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.21]
# Current Value of [w,b] = [[4.14,5.77],0.20]
# Current Value of [w,b] = [[4.14,5.77],0.20]
# Current Value of [w,b] = [[4.14,5.77],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.20]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.19]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.18]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.14,5.78],0.17]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.78],0.16]
# Current Value of [w,b] = [[4.15,5.79],0.16]
# Current Value of [w,b] = [[4.15,5.79],0.16]
# Current Value of [w,b] = [[4.15,5.79],0.16]
# Current Value of [w,b] = [[4.15,5.79],0.16]
# Current Value of [w,b] = [[4.15,5.79],0.16]
# Current Value of [w,b] = [[4.15,5.79],0.16]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.15]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.14]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.13]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.15,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.12]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.79],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.11]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# Current Value of [w,b] = [[4.16,5.80],0.10]
# ...
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.81],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.02]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# Current Value of [w,b] = [[4.18,5.82],0.01]
# ====================================================================================================
# Model with [4] (expectation:40):  39.9931640625
# ====================================================================================================
